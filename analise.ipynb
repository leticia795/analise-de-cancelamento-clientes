# %%
# !pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 5.9 MB/s eta 0:00:02
#    --------- ------------------------------ 1.8/8.1 MB 5.2 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.1 MB 5.5 MB/s eta 0:00:01
#    -------------------- ------------------- 4.2/8.1 MB 5.7 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.1 MB 5.8 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.1 MB 5.9 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 5.8 MB/s  0:00:01
# ...
#
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv('dados.csv')
df.head()
# Out:
#    clientes  tempo  cancelou
# 0        10      2         1
# 1        20      4         1
# 2        30      6         0
# 3        40      8         0
# 4        15      3         1

# %%
X = df[['clientes', 'tempo']]
y = df['cancelou']

# %%
modelo = LogisticRegression()
modelo.fit(X, y)
# Out:
# LogisticRegression()

# %%
previsoes = modelo.predict(X)
print(previsoes)
# Out:
# [1 1 0 0 1 0 0 1 0 0]

# %%
modelo.predict_proba(X)
# Out:
# array([[2.03277438e-06, 9.99997967e-01],
#        [3.62388199e-03, 9.96376118e-01],
#        [8.66799132e-01, 1.33200868e-01],
#        [9.99914120e-01, 8.58797182e-05],
#        [8.59771526e-05, 9.99914023e-01],
#        [9.99999964e-01, 3.59815272e-08],
#        [1.00000000e+00, 1.74110563e-11],
#        [1.33331852e-01, 8.66668148e-01],
#        [9.96380210e-01, 3.61978971e-03],
#        [9.99998242e-01, 1.75793574e-06]])

# %%
novo_cliente = pd.DataFrame([[30, 6]], columns=['clientes', 'tempo'])

print(modelo.predict(novo_cliente))
# Out:
# [0]

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
accuracy = accuracy_score(y, previsoes)
print("Acurácia:", accuracy)
# Out:
# Acurácia: 1.0

# %%
confusion_matrix(y, previsoes)
# Out:
# array([[6, 0],
#        [0, 4]])

# %%
print(classification_report(y, previsoes))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00         4
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# weighted avg       1.00      1.00      1.00        10

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(
    X, y, test_size=0.5, random_state=42
)

# %%
modelo = LogisticRegression()
modelo.fit(X_treino, y_treino)
# Out:
# LogisticRegression()

# %%
previsoes = modelo.predict(X_teste)

# %%
print("Acurácia:", accuracy_score(y_teste, previsoes))
print(confusion_matrix(y_teste, previsoes))
print(classification_report(y_teste, previsoes))
# Out:
# Acurácia: 0.8
# [[2 0]
#  [1 2]]
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       1.00      0.67      0.80         3
#
#     accuracy                           0.80         5
#    macro avg       0.83      0.83      0.80         5
# weighted avg       0.87      0.80      0.80         5

# %%
# !pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.3 MB 4.3 MB/s eta 0:00:02
#    ------ --------------------------------- 1.3/8.3 MB 4.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/8.3 MB 3.6 MB/s eta 0:00:02
#    ------------- -------------------------- 2.9/8.3 MB 3.9 MB/s eta 0:00:02
#    ------------------- -------------------- 3.9/8.3 MB 3.9 MB/s eta 0:00:02
#    ------------------------- -------------- 5.2/8.3 MB 4.3 MB/s eta 0:00:01
#    ------------------------------- -------- 6.6/8.3 MB 4.6 MB/s eta 0:00:01
#    ------------------------------------ --- 7.6/8.3 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 4.5 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------- ----------------- 1.3/2.3 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 6.5 MB/s  0:00:00
# ...

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

plt.scatter(df['tempo'], df['clientes'], c=df['cancelou'])
plt.xlabel("Tempo")
plt.ylabel("Clientes")
plt.title("Distribuição de Cancelamento")
plt.show()

# %%
plt.savefig("grafico.png")

# %%
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure()

plt.scatter(
    df['tempo'], 
    df['clientes'], 
    c=df['cancelou']
)

plt.xlabel("Tempo de relacionamento (meses)")
plt.ylabel("Quantidade de clientes")
plt.title("Análise de Cancelamento de Clientes")

plt.grid()

plt.savefig("imagens/grafico.png")  # salva direto na pasta

plt.show()
